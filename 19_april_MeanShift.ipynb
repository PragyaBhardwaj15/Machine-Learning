# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
sns.set_style('whitegrid')

# %%
centers_defined = [[2,2,2],[7,7,7],[5,13,13]]

# %%
X,_ = make_blobs(n_samples=150,centers=centers_defined,cluster_std=0.6)

# %%
X
# Out:
# array([[ 7.12980924,  6.32791418,  6.42400663],
#        [ 6.82117741, 12.02978634, 12.86792709],
#        [ 5.55626173, 12.91300353, 13.13401039],
#        [ 5.43257713, 12.56583998, 12.57817994],
#        [ 5.10544675, 12.78849024, 12.76325434],
#        [ 1.75841628,  1.98526777,  3.26621929],
#        [ 1.18276672,  2.06060199,  1.68597492],
#        [ 6.42796188,  7.66836071,  8.2019011 ],
#        [ 5.67933511, 12.41120405, 12.6475802 ],
#        [ 1.84596177,  2.13993579,  1.65155895],
#        [ 1.31359058,  2.91574249,  2.57199166],
#        [ 6.41205384, 12.08129896, 13.12020184],
#        [ 4.96073536, 13.44078076, 13.33498555],
#        [ 1.92711861,  2.72315059,  1.23081738],
#        [ 7.41921826,  7.57632353,  8.59032272],
#        [ 1.47728109,  2.33341408,  1.64687657],
#        [ 4.41202077, 12.76002321, 14.0384703 ],
#        [ 5.81489146,  6.5293988 ,  7.31774417],
#        [ 1.50062963,  2.27809926,  0.8306535 ],
#        [ 1.225307  ,  1.14762099,  2.25976979],
# ...

# %%
fig = plt.figure(figsize=(8,12))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2])
plt.show()

# %% [markdown]
# # Meanshift

# %%
from sklearn.cluster import MeanShift

# %%
ms = MeanShift()
ms.fit(X)
# Out:
# MeanShift()

# %%
cluster_pred = ms.fit_predict(X)
cluster_pred
# Out:
# array([0, 1, 1, 1, 1, 2, 2, 0, 1, 2, 2, 1, 1, 2, 0, 2, 1, 0, 2, 2, 0, 1,
#        1, 0, 0, 1, 2, 0, 2, 0, 1, 2, 1, 2, 2, 1, 0, 0, 0, 1, 2, 2, 1, 0,
#        0, 0, 0, 2, 2, 1, 0, 1, 2, 0, 1, 2, 2, 2, 1, 0, 2, 2, 2, 2, 0, 2,
#        1, 0, 2, 1, 2, 2, 1, 0, 1, 2, 1, 1, 0, 0, 0, 1, 2, 2, 2, 0, 0, 1,
#        1, 0, 2, 2, 1, 1, 1, 0, 2, 1, 0, 1, 2, 0, 1, 0, 0, 0, 1, 1, 2, 1,
#        2, 1, 2, 2, 0, 1, 2, 1, 0, 0, 1, 2, 0, 0, 1, 0, 0, 1, 0, 1, 0, 2,
#        1, 2, 0, 1, 0, 2, 2, 0, 0, 1, 2, 2, 1, 0, 0, 0, 1, 2], dtype=int64)

# %%
fig = plt.figure(figsize=(8,12))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],cmap='rainbow',c=cluster_pred)
plt.show()

# %% [markdown]
# #  kmeans

# %%
from sklearn.cluster import KMeans

# %%
kmean = KMeans(3)
kmean.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
identified_cluster = kmean.fit_predict(X)
identified_cluster
# Out:
# array([2, 0, 0, 0, 0, 1, 1, 2, 0, 1, 1, 0, 0, 1, 2, 1, 0, 2, 1, 1, 2, 0,
#        0, 2, 2, 0, 1, 2, 1, 2, 0, 1, 0, 1, 1, 0, 2, 2, 2, 0, 1, 1, 0, 2,
#        2, 2, 2, 1, 1, 0, 2, 0, 1, 2, 0, 1, 1, 1, 0, 2, 1, 1, 1, 1, 2, 1,
#        0, 2, 1, 0, 1, 1, 0, 2, 0, 1, 0, 0, 2, 2, 2, 0, 1, 1, 1, 2, 2, 0,
#        0, 2, 1, 1, 0, 0, 0, 2, 1, 0, 2, 0, 1, 2, 0, 2, 2, 2, 0, 0, 1, 0,
#        1, 0, 1, 1, 2, 0, 1, 0, 2, 2, 0, 1, 2, 2, 0, 2, 2, 0, 2, 0, 2, 1,
#        0, 1, 2, 0, 2, 1, 1, 2, 2, 0, 1, 1, 0, 2, 2, 2, 0, 1])

# %%
fig = plt.figure(figsize=(8,12))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],cmap='rainbow',c=identified_cluster)
plt.show()
